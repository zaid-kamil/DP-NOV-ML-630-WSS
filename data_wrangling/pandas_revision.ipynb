# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/digipodium/Datasets/main/regression/automobile.csv', index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.head() # first 5 records
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df.head(2)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
#
# [2 rows x 26 columns]

# %%
df.loc[100] # get a record by entry
# Out:
# symboling                 0
# normalized-losses       106
# make                 nissan
# fuel-type               gas
# aspiration              std
# num-of-doors           four
# body-style            sedan
# drive-wheels            fwd
# engine-location       front
# wheel-base             97.2
# length                173.4
# width                  65.2
# height                 54.7
# curb-weight            2302
# engine-type             ohc
# num-of-cylinders       four
# engine-size             120
# fuel-system            2bbl
# bore                   3.33
# stroke                 3.47
# compression-ratio       8.5
# horsepower               97
# peak-rpm               5200
# city-mpg                 27
# highway-mpg              34
# price                  9549
# Name: 100, dtype: object

# %%
df.iloc[:100] # first 100 entries
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 95          1               128       nissan       gas        std
# 96          1               122       nissan       gas        std
# 97          1               103       nissan       gas        std
# 98          2               168       nissan       gas        std
# 99          0               106       nissan       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df['horsepower'] # series output
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: object

# %%
cols= ['curb-weight', 'engine-size']
df[cols]
# Out:
#      curb-weight  engine-size
# 0           2548          130
# 1           2548          130
# 2           2823          152
# 3           2337          109
# 4           2824          136
# ..           ...          ...
# 200         2952          141
# 201         3049          141
# 202         3012          173
# 203         3217          145
# 204         3062          141
#
# [205 rows x 2 columns]

# %%
df[['price', 'engine-size','horsepower']]
# Out:
#      price  engine-size horsepower
# 0    13495          130        111
# 1    16500          130        111
# 2    16500          152        154
# 3    13950          109        102
# 4    17450          136        115
# ..     ...          ...        ...
# 200  16845          141        114
# 201  19045          141        160
# 202  21485          173        134
# 203  22470          145        106
# 204  22625          141        114
#
# [205 rows x 3 columns]

# %%
df.iloc[:100, :5] # first 100 records, first 5 columns
# Out:
#     symboling normalized-losses         make fuel-type aspiration
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# ..        ...               ...          ...       ...        ...
# 95          1               128       nissan       gas        std
# 96          1               122       nissan       gas        std
# 97          1               103       nissan       gas        std
# 98          2               168       nissan       gas        std
# 99          0               106       nissan       gas        std
#
# [100 rows x 5 columns]

# %%
df.loc[:100, ['price','engine-size']]
# Out:
#      price  engine-size
# 0    13495          130
# 1    16500          130
# 2    16500          152
# 3    13950          109
# 4    17450          136
# ..     ...          ...
# 96    7499           97
# 97    7999           97
# 98    8249           97
# 99    8949          120
# 100   9549          120
#
# [101 rows x 2 columns]

# %%
df.index[-10:]
# Out:
# Int64Index([195, 196, 197, 198, 199, 200, 201, 202, 203, 204], dtype='int64')

# %%
# remove last 10 rows
df.drop(df.index[-10:], inplace=True) # inplace should be used after checking

# %%
cols_to_drop = ['symboling', 'normalized-losses', 'fuel-type']
df.drop(cols_to_drop, axis=1, inplace=True)

# %%
df.drop(df.columns[:3], axis=1)
# Out:
#       body-style drive-wheels engine-location  wheel-base  length  width  \
# 0    convertible          rwd           front        88.6   168.8   64.1
# 1    convertible          rwd           front        88.6   168.8   64.1
# 2      hatchback          rwd           front        94.5   171.2   65.5
# 3          sedan          fwd           front        99.8   176.6   66.2
# 4          sedan          4wd           front        99.4   176.6   66.4
# ..           ...          ...             ...         ...     ...    ...
# 190    hatchback          fwd           front        94.5   165.7   64.0
# 191        sedan          fwd           front       100.4   180.2   66.9
# 192        sedan          fwd           front       100.4   180.2   66.9
# 193        wagon          fwd           front       100.4   183.1   66.9
# 194        sedan          rwd           front       104.3   188.8   67.2
#
#      height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
# boolean filter
df[df['price'] == '?']
# Out:
#         make aspiration num-of-doors body-style drive-wheels engine-location  \
# 9       audi      turbo          two  hatchback          4wd           front
# 44     isuzu        std          two      sedan          fwd           front
# 45     isuzu        std         four      sedan          fwd           front
# 129  porsche        std          two  hatchback          rwd           front
#
#      wheel-base  length  width  height  ...  engine-size fuel-system  bore  \
# 9          99.5   178.2   67.9    52.0  ...          131        mpfi  3.13
# 44         94.5   155.9   63.6    52.0  ...           90        2bbl  3.03
# 45         94.5   155.9   63.6    52.0  ...           90        2bbl  3.03
# 129        98.4   175.7   72.3    50.5  ...          203        mpfi  3.94
#
#      stroke compression-ratio horsepower peak-rpm  city-mpg highway-mpg price
# 9      3.40               7.0        160     5500        16          22     ?
# ...

# %%
df.replace('?', np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# make                 0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.dropna(subset=['price'], inplace=True)
df.shape
# Out:
# (191, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191 entries, 0 to 194
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               191 non-null    object
#  1   aspiration         191 non-null    object
#  2   num-of-doors       189 non-null    object
#  3   body-style         191 non-null    object
#  4   drive-wheels       191 non-null    object
#  5   engine-location    191 non-null    object
#  6   wheel-base         191 non-null    float64
#  7   length             191 non-null    float64
#  8   width              191 non-null    float64
#  9   height             191 non-null    float64
#  10  curb-weight        191 non-null    int64
#  11  engine-type        191 non-null    object
#  12  num-of-cylinders   191 non-null    object
#  13  engine-size        191 non-null    int64
#  14  fuel-system        191 non-null    object
#  15  bore               187 non-null    object
# ...

# %%
df['price'] = df['price'].astype('int')

# %%
df['average'] = df['price'] / df['city-mpg']

# %%
df
# Out:
#             make aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero        std          two  convertible          rwd
# 1    alfa-romero        std          two  convertible          rwd
# 2    alfa-romero        std          two    hatchback          rwd
# 3           audi        std         four        sedan          fwd
# 4           audi        std         four        sedan          4wd
# ..           ...        ...          ...          ...          ...
# 190   volkswagen        std          two    hatchback          fwd
# 191   volkswagen        std         four        sedan          fwd
# 192   volkswagen      turbo         four        sedan          fwd
# 193   volkswagen        std         four        wagon          fwd
# 194        volvo        std         four        sedan          rwd
#
#     engine-location  wheel-base  length  width  height  ...  fuel-system  \
# 0             front        88.6   168.8   64.1    48.8  ...         mpfi
# ...

# %%
df['price'].plot(kind='line', figsize=(15,5))
# Out:
# <AxesSubplot: >

# %%
df['price'].plot(kind='box', figsize=(10,3), meanline=True,
    showmeans=True, vert=False, notch=True)
# Out:
# <AxesSubplot: >

# %%
df['price'].describe()
# Out:
# count      191.000000
# mean     12926.062827
# std       8028.532208
# min       5118.000000
# 25%       7713.500000
# 50%       9988.000000
# 75%      15667.500000
# max      45400.000000
# Name: price, dtype: float64

# %%
df['horsepower'] = df['horsepower'].astype('float')

# %%
df['horsepower'].plot(kind='box', figsize=(10,3), meanline=True,
    showmeans=True, vert=False, notch=True)
# Out:
# <AxesSubplot: >

# %%
df['city-mpg'].min()
# Out:
# 13

# %%
def milage_bin(val):
    if val < 20:
        return "Low Mileage"
    elif val < 35:
        return "Medium Mileage"
    else:
        return "High Mileage"

# %%
df['mileage-group'] = df['city-mpg'].apply(milage_bin)
df.head(3)
# Out:
#           make aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero        std          two  convertible          rwd
# 1  alfa-romero        std          two  convertible          rwd
# 2  alfa-romero        std          two    hatchback          rwd
#
#   engine-location  wheel-base  length  width  height  ...  bore stroke  \
# 0           front        88.6   168.8   64.1    48.8  ...  3.47   2.68
# 1           front        88.6   168.8   64.1    48.8  ...  3.47   2.68
# 2           front        94.5   171.2   65.5    52.4  ...  2.68   3.47
#
#   compression-ratio  horsepower peak-rpm city-mpg highway-mpg  price  \
# 0               9.0       111.0     5000       21          27  13495
# 1               9.0       111.0     5000       21          27  16500
# 2               9.0       154.0     5000       19          26  16500
#
#       average   mileage-group
# 0  642.619048  Medium Mileage
# 1  785.714286  Medium Mileage
# 2  868.421053     Low Mileage
#
# ...
